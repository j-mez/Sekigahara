# %%
from IPython.display import Image
from collections import Counter

# %%
tokugawa3 = Block("Black","Tokugawa",3,"Army")
m3 = Block("Black","Maeda",3,"Cavalry")

print(tokugawa3.info_self())
tok_stack = BlockStack([],"Black")
tok_stack.add_block(tokugawa3)
tok_stack.add_block(tokugawa3)
tok_stack.add_block(m3)
tok_stack.add_block(m3)
tok_stack.add_block(tokugawa3)

tok_stack.display_stack_self()
tok_stack.remove_block(4)
tok_stack.display_stack_self()
# Out:
# TOKUGAWA ⚔️⚔️⚔️(3)
# Black Stack, Size: 5
# 0. TOKUGAWA ⚔️⚔️⚔️(3)
# 1. TOKUGAWA ⚔️⚔️⚔️(3)
# 2. TOKUGAWA ⚔️⚔️⚔️(3)
# 3. MAEDA 🐎(3)
# 4. MAEDA 🐎(3)
# Black Stack, Size: 4
# 0. TOKUGAWA ⚔️⚔️⚔️(3)
# 1. TOKUGAWA ⚔️⚔️⚔️(3)
# 2. TOKUGAWA ⚔️⚔️⚔️(3)
# 3. MAEDA 🐎(3)
# True

# %%
#Block stuff
class Block(object):
    color = ""
    clan = ""
    impact = 0
    b_type = ""

    # The class "constructor" - It's actually an initializer 
    def __init__(self, color, clan, impact, b_type):
        self.color = color
        self.clan = clan
        self.impact = impact
        self.b_type = b_type
    
    def info_self(self):
        if self.b_type=="Leader":
            symbol_rep = "🚩"
        elif self.b_type=="Army":
            symbol_rep = "⚔️"*self.impact #★
        elif self.b_type=="Cavalry":
            symbol_rep = "🐎"
        elif self.b_type=="Arquebus":
            symbol_rep = "🔫"
        else:
            symbol_rep = "★"
        return "{} {}({})".format(self.clan.upper(),symbol_rep,self.impact)
        
class BlockStack(object):
    block_array = []
    color = ""
    def __init__(self,block_array,color):
        self.block_array = block_array
        self.color = color
        
    def remove_block(self,block_index):
        '''
        Returns removed block
        '''
        return self.block_array.pop(block_index)
    
#     def combine_stacks(other_BlockStack):
#         '''
#         Returns new BlockStack with combined units
#         WILL NEED TO REMOVE OTHER BLOCKSTACK WHEN THEY COMBINE
        
#         '''
    def add_block(self,new_block):
        self.block_array.append(new_block)
        return True
    
    def split_stack(self,block_inds):
        '''
        Splits BlockStack into 2 stacks
        Returns two BlockStacks
        '''
        
    def sort_by_clan(self):
        '''
        Sorts blocks by clan
        '''
        self.block_array.sort(key=lambda block: block.clan, reverse=True)
        
    def display_stack_self(self):
        self.sort_by_clan()
        print("{} Stack, Size: {}".format(self.color,len(self.block_array)))
        index=0
        for block in self.block_array:
            print("{}. {}".format(index, block.info_self()))
            index+=1
        return True
    
    def display_block_other(self):
        print("{} {} Blocks".format(len(self.block_array),color))

# %%
#DECK OF CARDS

# %%
#UNITS
tokugawa_units = [
    Block("Black","Sendai",1,"Leader"),
    Block("Black","Sendai",1,"Cavalry"),
    Block("Black","Sendai",1,"Cavalry"),
    Block("Black","Sendai",1,"Arquebus"),
    Block("Black","Sendai",2,"Army"),
    Block("Black","Sendai",2,"Army"),
    Block("Black","Sendai",3,"Army"),
    Block("Black","Sendai",3,"Army"),
    Block("Black","Sendai",3,"Army"),
    Block("Black","Maeda",1,"Leader"),
    Block("Black","Maeda",1,"Cavalry"),
    Block("Black","Maeda",1,"Cavalry"),
    Block("Black","Maeda",1,"Arquebus"),
    Block("Black","Maeda",2,"Army"),
    Block("Black","Maeda",2,"Army"),
    Block("Black","Maeda",2,"Army"),
    Block("Black","Maeda",3,"Army"),
    Block("Black","Maeda",3,"Army"),
    Block("Black","Maeda",3,"Army"),
    Block("Black","Fukushima",1,"Leader"),
    Block("Black","Fukushima",1,"Cavalry"),
    Block("Black","Fukushima",1,"Arquebus"),
    Block("Black","Fukushima",1,"Arquebus"),
    Block("Black","Fukushima",2,"Army"),
    Block("Black","Fukushima",2,"Army"),
    Block("Black","Fukushima",3,"Army"),
    Block("Black","Fukushima",3,"Army"),
    Block("Black","Fukushima",3,"Army")


    
]
ishida_units = []

# %%
#graph stuff
def create_edgelist():
        '''
        Create edge list
        '''
        edge_list = {
            ("Ayabe","Himeji"):"road",
            ("Ayabe","Miyazu"):"road",
            ("Ayabe","Kyoto"):"road",
            ("Himeji","Osaka"):"road",
            ("Osaka","Kyoto"):"highway",
            ("Osaka","Wakayama"):"road",
            ("Tanabe","Wakayama"):"road",
            ("Tanabe","Kumano"):"road",
            ("Anotsu","Kumano"):"road",
            ("Anotsu","Kuwana"):"road",
            ("Minakuchi","Kyoto"):"highway",
            ("Kyoto","Sawayama"):"highway",
            ("Minakuchi","Kuwana"):"highway",
            ("Tsuruga","Miyazu"):"road",
            ("Tsuruga","Sawayama"):"road",
            ("Kiyosu","Kuwana"):"highway",
            ("Kiyosu","Okazaki"):"highway",
            ("Kiyosu","Gifu"):"road",
            ("Gifu","Sawayama"):"highway",
            ("Gifu","Iwamura"):"highway",
            ("Hamamatsu","Okazaki"):"highway",
            ("Hamamatsu","Sunpu"):"highway",
            ("Kiso","Iwamura"):"highway",
            ("Tsuruga","Kitanosho"):"road",
            ("Kanazawa","Kitanosho"):"road",
            ("Kanazawa","Toyama"):"road",
            ("Takeda","Toyama"):"road",
            ("Takeda","Arato"):"road",
            ("Takeda","Nagaoka"):"road",
            ("Ueda","Arato"):"road",
            ("Ueda","Saku"):"road",
            ("Kiso","Suwa"):"highway",
            ("Saku","Suwa"):"highway",
            ("Saku","Takasaki"):"highway",
            ("Oshi","Takasaki"):"highway",
            ("Shibukawa","Takasaki"):"road",
            ("Shibukawa","Uonuma"):"road",
            ("Nagaoka","Uonuma"):"road",
            ("Nagaoka","Niigata"):"road",
            ("Oshi","Edo"):"highway",
            ("Kiso","Matsumoto"):"road",
            ("Arato","Matsumoto"):"road",
            ("Numazu","Sunpu"):"highway",
            ("Numazu","Hakone"):"highway",
            ("Numazu","Kofu"):"road",
            ("Suwa","Kofu"):"road",
            ("Edo","Hakone"):"highway",
            ("Edo","Oyama"):"road",
            ("Utsunomiya","Oyama"):"road",
            ("Utsunomiya","Shirakawa"):"road",
            ("Edo","Mito"):"road",
            ("Iwaki","Mito"):"road",
            ("Iwaki","Soma"):"road",
            ("Sendai","Soma"):"road",
            ("Sendai","Yamagata"):"road",
            ("Murakami","Yamagata"):"road",
            ("Murakami","Niigata"):"road",
            ("Tsugawa","Niigata"):"road",
            ("Tsugawa","Aizu"):"road",
            ("Shirakawa","Aizu"):"road",
            ("Sendai","Nihonmatsu"):"road",
            ("Shirakawa","Nihonmatsu"):"road",
        }
        edge_list_2 = {}
        for edge in edge_list: #make every inverse path
            loc1,loc2 = edge[0],edge[1]
            edge_type = edge_list[edge]
            edge_list_2[(loc2,loc1)]=edge_type
            
        edge_list = {**edge_list, **edge_list_2}
        
        return edge_list
edges = create_edgelist()

cities = set(edge[0] for edge in edges)
# city_dict
# city_dict = {}

# for edge in edges:
#     loc1,loc2 = edge[0],edge[1]
#     if loc1 not in city_dict:
#         city_dict[loc1] = [loc2]
#     else:
#         city_dict[loc1].append(loc2)

# for city in city_dict:
#     print("{} = {}".format(city,len(city_dict[city])))


#castle locations
castles = ["Miyazu","Osaka","Anotsu","Okazaki",
          "Gifu","Kanazawa","Ueda","Hakone",
          "Aizu"]

#resource locations
resource_locs = ["Niigata","Shirakawa","Takasaki",
                 "Takeda","Edo","Kiso",
                 "Tsuruga","Kuwana","Kiyoto"]
#Capitals
capital_dict = {"Kiyoto":"yellow","Edo":"black"}

# %%
#Block and Graph Stuff

city_block_stacks = {} #city:{}

def initialize_empty_city_block_stacks():
    global city_block_stacks
    global cities
    city_block_stacks = {}
    for city in cities:
        city_block_stacks[city]={"Black":[],"Yellow":[]}
initialize_empty_city_block_stacks()

def initialize_units:

# %%
#Movement

# def num_available_moves(start,num_blocks,leader_present,force_march=False):
#     '''
#     Rules
#         Base movement: 1 location
#         Highway = 
    
#     Returns number of available move locations
#     '''

def is_valid_movement(start,end,num_blocks,leader_present,force_march=False):
    '''
    Rules for movement
        Base move: 1 location
        Along highway: +1
        Leadership Present(start at Castle or Possess leader): +1
        Force March(discard a card for +1): +1
        1-4 Blocks: 0
        5-8 Blocks: -1
        9-12 Blocks: -2
        13-16 Blocks: -3
        17+ Blocks: -4(cannot move)
    '''
    #Todo
    pass

# %%
#Global Variables
global recruit_box_B = []
global recruit_box_Y = []

global week = 1

# %%
Image(url="SekiMap.jpg")
# Out:
# <img src="SekiMap.jpg"/>

# %%
def combat(yellow_stack,black_stack):
    """
    simulate combat, exit when one team surrenders or stacks are destroyed
    """
